# %%
import pandas as pd
from matplotlib import pyplot as plt
from sqlalchemy import create_engine

#Connect to remote database and get data from table
SQL_CONNECTION = create_engine("mysql+pymysql://root:Mbw20030714@192.168.194.161:3306/itcast_shop_2021443754")

# %%
#每天订单支付的总金额、订单的总笔数可视化
SQL_QUERY = "select * from app_order_total;"
data = pd.read_sql_query(SQL_QUERY, SQL_CONNECTION)
columns_name = data.columns.values.tolist()
del columns_name[:1]
data = data.loc[0].tolist()
X = columns_name[1:]
Y = data[2:]
bar_colors = ['tab:red', 'tab:blue']
fig, ax = plt.subplots()
ax.bar(X, Y, color=bar_colors)
ax.set_ylabel('Count')
ax.set_title('2019年9月5日销售总额与销售总量')
plt.rcParams['font.sans-serif'] = ['Heiti TC']
plt.show()

# %%
#统计每天下过订单的不同用户总数
SQL_QUERY = "select * from app_order_user;"
data = pd.read_sql_query(SQL_QUERY, SQL_CONNECTION)
data = data.loc[:9]
print(data)
data_columns = data.columns.values.tolist()
print(data_columns)
del data_columns[:1]
del data_columns[1:]
print(data_columns)
X = data.loc[:, "dt"].tolist()
Y = data.loc[:, "total_user_cnt"].tolist()
print(Y)
fig, ax = plt.subplots()
bar_colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange']
ax.set_title("每天下过订单的不同用户总数")
ax.bar(X, Y,color=bar_colors)
plt.show()
# Out:
#    id          dt  total_user_cnt
# 0   1  2019-06-22              19
# 1   2  2019-07-29               1
# 2   3  2019-09-05              11
# 3   4  2019-06-22              19
# 4   5  2019-07-29               1
# 5   6  2019-09-05              11
# 6   7  2019-06-22              19
# 7   8  2019-07-29               1
# 8   9  2019-09-05              11
# 9  10  2019-06-22              19
# ['id', 'dt', 'total_user_cnt']
# ['dt']
# [19, 1, 11, 19, 1, 11, 19, 1, 11, 19]

# %%
#商品销量TOP5可视化
SQL_QUERY = "select * from app_goods_top5;"
data = pd.read_sql_query(SQL_QUERY, SQL_CONNECTION)
data = data.loc[:4]
print(data)
X = data.loc[:, "goodsName"].tolist()
print(X)
Y = data.loc[:, "cnt"].tolist()
print(Y)
fig, ax = plt.subplots()
bar_colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange', 'tab:purple']
ax.bar(X, Y, color=bar_colors)
ax.set_title("2019年9月5日商品销量TOP5")
plt.show()
# Out:
#    id          dt     goodsName  cnt
# 0   1  2019-09-05  FirstLove香皂花    7
# 1   2  2019-09-05       溢彩年华置物架    7
# 2   3  2019-09-05          神舟战神    6
# 3   4  2019-09-05        家乐铭品鞋柜    6
# 4   5  2019-09-05       阿迪达斯休闲鞋    6
# ['FirstLove香皂花', '溢彩年华置物架', '神舟战神', '家乐铭品鞋柜', '阿迪达斯休闲鞋']
# [7, 7, 6, 6, 6]

# %%
SQL_QUERY = "select * from app_cat_cnt;"
data = pd.read_sql_query(SQL_QUERY, SQL_CONNECTION)
data = data.loc[:8]
print(data)
X = data.loc[:, "catName"].tolist()
print(X)
Y = data.loc[:, "cnt"].tolist()
print(Y)

fig, ax = plt.subplots()
bar_colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange', 'tab:purple']
ax.bar(X, Y, color=bar_colors)
ax.set_title("2019年6月22日不同商品分类产生的订单")
plt.show()
# Out:
#    id      daystr catName  cnt
# 0   1  2019-06-22    智能手表    1
# 1   2  2019-06-22      套装    2
# 2   3  2019-06-22    浴室用品    1
# 3   4  2019-06-22    家庭护理    3
# 4   5  2019-06-22    花盆花器    2
# 5   6  2019-06-22      吉他    6
# 6   7  2019-06-22     永生花    1
# 7   8  2019-06-22      瑞表    2
# 8   9  2019-06-22      鲜花    8
# ['智能手表', '套装', '浴室用品', '家庭护理', '花盆花器', '吉他', '永生花', '瑞表', '鲜花']
# [1, 2, 1, 3, 2, 6, 1, 2, 8]
